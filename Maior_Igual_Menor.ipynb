# %%
i = int(input('Insira um número:'))
if i < 10:
    print(i ,' é menor que 10')
elif i > 10:
    print(i, 'é maior que 10')
elif i == 10:
    print(i, 'é igual a 10')
    
else:
    print('erro')
# Out:
# Insira um número:90
# 90 é maior que 10
